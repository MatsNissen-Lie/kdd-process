# %%
# %load_ext autoreload
# %autoreload 2

# Processing each task

from pandas import DataFrame
from pathlib import Path
import sys

# Add the project directory to sys.path
project_dir = Path.cwd().parent  # Adjust as needed to point to your project root
sys.path.append(str(project_dir))

# Import the module
from utils.dslabs_functions import get_variable_types, encode_cyclic_variables, dummify
from utils.data_loader import DataLoader


dataloader = DataLoader()
data, target = dataloader.get_security_classification_dataset_and_target()
# data: DataFrame = read_csv("data/stroke_mvi.csv", index_col="id", na_values="")
vars: dict[str, list] = get_variable_types(data)

yes_no: dict[str, int] = {"no": 0, "No": 0, "yes": 1, "Yes": 1}
residence_type_values: dict[str, int] = {"Rural": 0, "Urban": 1}

encoding: dict[str, dict[str, int]] = {
    # "LAW_CAT_CD": residence_type_values,
    # "hypertension": yes_no,
}
df: DataFrame = data.replace(encoding, inplace=False)
df.head()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#    ARREST_KEY ARREST_DATE  PD_CD                                    PD_DESC  \
# 0   167627343  2017-08-01  779.0  PUBLIC ADMINISTRATION,UNCLASSIFIED FELONY
# 1   140205878  2014-12-16  750.0                           RESISTING ARREST
# 2   141497929  2015-03-19  639.0                    AGGRAVATED HARASSMENT 2
# 3    61262720  2009-04-29  969.0            TRAFFIC,UNCLASSIFIED INFRACTION
# 4    71392833  2010-02-18  567.0                MARIJUANA, POSSESSION 4 & 5
#
#    KY_CD                                    OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0  126.0                      MISCELLANEOUS PENAL LAW  PL 215510D          F
# 1  359.0       OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2053000          M
# 2  361.0  OFF. AGNST PUB ORD SENSBLTY & RGHTS TO PRIV  PL 2403002          M
# 3  881.0                     OTHER TRAFFIC INFRACTION  VTL051101A          M
# 4  235.0                              DANGEROUS DRUGS  PL 2211001          M
#
#   ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 0           K               62                0.0     25-44        M
# 1           M               25                4.0     25-44        M
# 2           M               30                0.0     18-24        M
# 3           M               28                0.0     25-44        M
# 4           S              120                0.0     25-44        M
#
#         PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0           WHITE    987500.0    157358.0  40.598595 -73.988298
# 1           BLACK   1004138.0    226326.0  40.787875 -73.928182
# 2  WHITE HISPANIC    999751.0    241188.0  40.828675 -73.943990
# 3           BLACK    999537.0    232842.0  40.805768 -73.944782
# 4           WHITE    944398.0    165687.0  40.621368 -74.143557
#
#   CLASS__security
# 0              NY
# 1           nonNY
# 2              NY
# 3              NY
# 4              NY

# %%
for v in vars["symbolic"]:
    print(v, data[v].unique())
# Out:
# PD_DESC ['PUBLIC ADMINISTRATION,UNCLASSIFIED FELONY' 'RESISTING ARREST'
#  'AGGRAVATED HARASSMENT 2' 'TRAFFIC,UNCLASSIFIED INFRACTION'
#  'MARIJUANA, POSSESSION 4 & 5' 'PUBLIC ADMINISTRATION,UNCLASSI'
#  'CONTEMPT,CRIMINAL' 'CONTROLLED SUBSTANCE, POSSESSION 7'
#  'IDENTITY THFT-1' 'CONTROLLED SUBSTANCE, INTENT TO SELL 5'
#  'THEFT OF SERVICES, UNCLASSIFIED' 'RECKLESS ENDANGERMENT 1'
#  'INTOXICATED DRIVING,ALCOHOL' 'ASSAULT 3' 'TRESPASS 2, CRIMINAL'
#  'LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED'
#  'MISCHIEF,CRIMINAL     UNCLASSIFIED 4TH DEG' 'ASSAULT 2,1,UNCLASSIFIED'
#  'BRIBERY,PUBLIC ADMINISTRATION' 'LARCENY,PETIT FROM OPEN AREAS,'
#  'ROBBERY,UNCLASSIFIED,OPEN AREAS' 'TRAFFIC,UNCLASSIFIED MISDEMEAN'
#  'MARIJUANA, SALE 4 & 5' 'FORGERY,ETC.-MISD.' 'WEAPONS, POSSESSION, ETC'
#  'TRESPASS 3, CRIMINAL' 'LARCENY,GRAND FROM PERSON,UNCLASSIFIED'
#  'LARCENY,PETIT FROM OPEN AREAS,UNCLASSIFIED' 'UNAUTHORIZED USE VEHICLE 2'
#  'CONTROLLED SUBSTANCE,POSSESS. 3' 'BURGLARY,UNCLASSIFIED,UNKNOWN TIME'
#  'TRAFFIC,UNCLASSIFIED MISDEMEANOR'
#  'DRUG PARAPHERNALIA,   POSSESSES OR SELLS 2' 'WEAPONS POSSESSION 3'
#  'CONTROLLED SUBSTANCE,INTENT TO SELL 3'
#  'FORGERY,ETC.,UNCLASSIFIED-FELONY' 'CONTROLLED SUBSTANCE,POSSESS. 1'
#  'CONTROLLED SUBSTANCE,SALE 3' 'CHECK,BAD' 'MENACING,UNCLASSIFIED'
#  'NY STATE LAWS,UNCLASSIFIED MISDEMEANOR' 'BAIL JUMPING 3'
#  'TRAFFIC,UNCLASSIFIED INFRACTIO' 'IMPERSONATION 2, PUBLIC SERVANT'
#  'LARCENY,GRAND FROM OPEN AREAS, UNATTENDED' 'PROSTITUTION'
#  'MISCHIEF,CRIMINAL,    UNCL 2ND DEG 3RD DEG' 'OBSTR BREATH/CIRCUL'
#  'CONTROLLED SUBSTANCE,SALE 2' 'STOLEN PROPERTY 3,POSSESSION'
#  'FALSE REPORT UNCLASSIFIED' 'NY STATE LAWS,UNCLASSIFIED FEL'
#  'LEWDNESS,PUBLIC' 'FALSE REPORT BOMB' 'NY STATE LAWS,UNCLASSIFIED FELONY'
#  'LARCENY,GRAND OF AUTO' 'FIREWORKS, SALE'
#  'ALCOHOLIC BEVERAGE CONTROL LAW' 'TAMPERING 1,CRIMINAL'
#  'CHILD, ENDANGERING WELFARE' 'BURGLARY,RESIDENCE,NIGHT'
#  'BURGLARY,UNCLASSIFIED,UNKNOWN' 'CONTROLLED SUBSTANCE, POSSESSI'
#  'TAX LAW' 'GAMBLING 1,PROMOTING,BOOKMAKING' 'RAPE 3'
#  'PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4'
#  'LOITERING FOR PROSTITUTION OR TO PATRONIZE' 'WEAPONS POSSESSION 1 & 2'
#  'STRANGULATION 1ST' 'PROSTITUTION, PATRONIZING 4, 3'
#  'UNAUTHORIZED USE VEHICLE 3' 'SEXUAL ABUSE 3,2'
#  'FORGERY,ETC.,UNCLASSIFIED-FELO' 'MISCHIEF,CRIMINAL,    UNCL 2ND'
#  'MURDER,UNCLASSIFIED' 'STOLEN PROPERTY 2,1,POSSESSION,UNCLASSIFIED'
#  'NY STATE LAWS,UNCLASSIFIED MIS' 'MARIJUANA, POSSESSION 1, 2 & 3'
#  'RECKLESS ENDANGERMENT 2' 'CRIMINAL CONTEMPT 1'
#  'CONTROLLED SUBSTANCE,POSSESS. 2' 'SALE OF UNAUTHORIZED RECORDINGS'
#  'ROBBERY,OPEN AREA UNCLASSIFIED' 'RECKLESS DRIVING'
#  'CONTROLLED SUBSTANCE,SALE 1' 'CONTROLLED SUBSTANCE, POSSESSION 4'
#  'CONTROLLED SUBSTANCE, POSSESSION 5' 'POSSESSION ANTI-SECURITY ITEM'
#  'BURGLARS TOOLS,UNCLASSIFIED' nan 'LEAVING SCENE-ACCIDENT-PERSONA'
#  'CRIMINAL MISCHIEF 4TH, GRAFFITI' 'ASSEMBLY,UNLAWFUL'
#  'CRIMINAL MISCHIEF,UNCLASSIFIED 4' 'TRESPASS 1,CRIMINAL'
#  'BAIL JUMPING 1 & 2' 'SEXUAL ABUSE 1' 'ACCOSTING,FRAUDULENT'
#  'IMPAIRED DRIVING,DRUG' 'MARIJUANA, SALE 1, 2 & 3'
#  'GAMBLING, DEVICE, POSSESSION' 'CONTROLLED SUBSTANCE, SALE 5'
#  'GAMBLING 2,PROMOTING,UNCLASSIFIED' 'CONTROLLED SUBSTANCE,INTENT TO'
#  'CONTROLLED SUBSTANCE, INTENT T' 'LARCENY,GRAND FROM PERSON,UNCL'
#  'AGRICULTURE & MARKETS LAW,UNCLASSIFIED' 'LARCENY,GRAND FROM OPEN AREAS,'
#  'FORGERY,PRESCRIPTION' 'ASSAULT 2,1,PEACE OFFICER'
#  'GAMBLING 1,PROMOTING,POLICY' 'COURSE OF SEXUAL CONDUCT AGAINST A CHILD'
#  'CONTROLLED SUBSTANCE,POSSESS.' 'IDENTITY THFT-2'
#  'POSSESSION HYPODERMIC INSTRUMENT' 'SODOMY 3' 'TAMPERING 3,2, CRIMINAL'
#  'FRAUD,UNCLASSIFIED-MISDEMEANOR,PART 1' 'CONSPIRACY 2, 1'
#  'CONTROLLED SUBSTANCE, SALE 4' 'RIOT 1' 'SODOMY 1'
#  'FRAUD,UNCLASSIFIED-FELONY' 'DRUG PARAPHERNALIA,   POSSESSE' 'RAPE 2'
#  'LEAVING THE SCENE / PROPERTY DAMAGE / INJURED ANIMAL' 'ARSON 2,3,4'
#  'MENACING 1ST DEGREE (VICT NOT PEACE OFFICER)'
#  'MANUFACTURE UNAUTHORIZED RECORDINGS'
#  'PROSTITUTION 3, PROMOTING UNDER 19' 'IMPRISONMENT 2,UNLAWFUL'
#  'DIS. CON.,AGGRAVATED' 'ESCAPE 2,1' 'LARCENY,GRAND BY EXTORTION'
#  'DRUG PARAPHERNALIA,   POSSESSES OR SELLS 1'
#  'MISCHIEF, CRIMINAL 3 & 2, OF MOTOR VEHICLE'
#  'ASSAULT POLICE/PEACE OFFICER' 'PROSTITUTION 4,PROMOTING&SECURING'
#  'COERCION 1' 'AGGRAVATED CRIMINAL CONTEMPT' 'FACILITATION 4, CRIMINAL'
#  'STOLEN PROPERTY 2,1,POSSESSION' 'CRIMINAL MIS 2 & 3'
#  'FORGERY,M.V. REGISTRATION' 'THEFT OF SERVICES, UNCLASSIFIE'
#  'PUBLIC ADMINISTATION,UNCLASS M' 'ENTERPRISE CORRUPTION'
#  'IMPERSONATION 2, PUBLIC SERVAN' 'FRAUD,UNCLASSIFIED-MISDEMEANOR'
#  'RIOT 2/INCITING' 'PROSTITUTION 3, PROMOTING UNDE'
#  'LARCENY,PETIT BY ACQUIRING LOS' 'LARCENY,GRAND BY ACQUIRING LOS'
#  'SALE SCHOOL GROUNDS' 'CHILD ABANDONMENT'
#  'IMPERSONATION 1, POLICE OFFICER' 'CRIMINAL MISCHIEF 4TH, GRAFFIT'
#  'FORGERY-ILLEGAL POSSESSION,VEHICLE IDENT. NU'
#  'MANUFACTURE UNAUTHORIZED RECOR' 'RAPE 1'
#  'PROSTITUTION 3,PROMOTING BUSINESS' 'PUBLIC SAFETY,UNCLASSIFIED MIS'
#  'MISCHIEF, CRIMINAL 3 & 2, OF M']
# OFNS_DESC ['MISCELLANEOUS PENAL LAW' 'OFFENSES AGAINST PUBLIC ADMINISTRATION'
#  'OFF. AGNST PUB ORD SENSBLTY & RGHTS TO PRIV' 'OTHER TRAFFIC INFRACTION'
#  'DANGEROUS DRUGS' 'THEFT-FRAUD' 'OTHER OFFENSES RELATED TO THEFT'
#  'INTOXICATED/IMPAIRED DRIVING' 'ASSAULT 3 & RELATED OFFENSES'
#  'CRIMINAL TRESPASS' 'GRAND LARCENY'
#  'CRIMINAL MISCHIEF & RELATED OFFENSES' 'FELONY ASSAULT' 'PETIT LARCENY'
#  'ROBBERY' 'VEHICLE AND TRAFFIC LAWS' 'OFFENSES INVOLVING FRAUD'
#  'DANGEROUS WEAPONS' 'BURGLARY' 'FORGERY' 'FRAUDS'
#  'OTHER STATE LAWS (NON PENAL LAW)' 'PROSTITUTION & RELATED OFFENSES'
#  'POSSESSION OF STOLEN PROPERTY 5' 'NYS LAWS-UNCLASSIFIED FELONY'
#  'INTOXICATED & IMPAIRED DRIVING' 'OTHER STATE LAWS'
#  'GRAND LARCENY OF MOTOR VEHICLE' 'OFFENSES AGAINST PUBLIC SAFETY'
#  'OFF. AGNST PUB ORD SENSBLTY &' 'ALCOHOLIC BEVERAGE CONTROL LAW'
#  'SEX CRIMES' 'OTHER STATE LAWS (NON PENAL LA' 'GAMBLING' 'RAPE'
#  'UNAUTHORIZED USE OF A VEHICLE 3 (UUV)' 'FORCIBLE TOUCHING'
#  'CRIMINAL MISCHIEF & RELATED OF' 'MURDER & NON-NEGL. MANSLAUGHTE'
#  'POSSESSION OF STOLEN PROPERTY' 'OFFENSES AGAINST THE PERSON'
#  'MURDER & NON-NEGL. MANSLAUGHTER' 'HARASSMENT'
#  'OFFENSES AGAINST PUBLIC ADMINI' "BURGLAR'S TOOLS" nan
#  'UNAUTHORIZED USE OF A VEHICLE' 'FRAUDULENT ACCOSTING' 'ARSON'
#  'DISRUPTION OF A RELIGIOUS SERVICE' 'ANTICIPATORY OFFENSES'
#  'OTHER OFFENSES RELATED TO THEF' 'CHILD ABANDONMENT/NON SUPPORT 1']
# LAW_CODE ['PL 215510D' 'PL 2053000' 'PL 2403002' 'VTL051101A' 'PL 2211001'
#  'PL 215510B' 'PL 2155003' 'PL 2200300' 'PL 1908003' 'PL 2200601'
#  'PL 1651503' 'PL 1202500' 'VTL11920F3' 'PL 1200001' 'PL 1401500'
#  'PL 1553004' 'PL 1450001' 'PL 1200501' 'PL 2154002' 'PL 1552500'
#  'PL 2155006' 'PL 1600500' 'PL 2402500' 'PL 1601502' 'VTL0511001'
#  'PL 1200002' 'PL 2214000' 'PL 1657100' 'PL 2650102' 'PL 140100A'
#  'PL 1553005' 'PL 2650101' 'PL 1650600' 'PL 2201609' 'PL 140251B'
#  'PL 1650800' 'VTL05110A4' 'PL 2205001' 'PL 2650201' 'PL 1401000'
#  'PL 1201001' 'PL 2201601' 'PL 1701003' 'PL 2202101' 'PL 2203901'
#  'PL 1900501' 'PL 1553001' 'PL 1402000' 'PL 1201401' 'LOC00000UM'
#  'PL 2211002' 'VTL05110MU' 'PL 2155500' 'PL 1902300' 'LOC00000AM'
#  'PL 1200502' 'PL 2155100' 'PL 2300000' 'PL 1450500' 'PL 215510C'
#  'PL 1553501' 'PL 1211100' 'PL 2204101' 'PL 1654000' 'PL 240503A'
#  'PL 1200700' 'PL 1601001' 'VTL05110FE' 'PL 2450000' 'PL 1200000'
#  'PL 1402501' 'VTL11920U3' 'PL 1701004' 'PL 1702500' 'VTL0511002'
#  'PL 160102A' 'PL 120052H' 'PL 265025B' 'PL 1553500' 'VTL11920U2'
#  'PL 2406100' 'VTL1220B01' 'VTL0511003' 'PL 2201604' 'PL 1553008'
#  'PL 27000M2' 'PL 2052501' 'CPL5700600' 'PL 24030M1' 'PL 2201603'
#  'VTL1192U2C' 'ABC0100001' 'PL 1452000' 'PL 140100E' 'PL 2601001'
#  'VTL11920M2' 'PL 1402502' 'PL 1601503' 'PL 2200901' 'PL 1201500'
#  'PL 2211500' 'PL 2205003' 'TAX18140B2' 'PL 2252001' 'PL 1302503'
#  'PL 1950500' 'CPL5702600' 'PL 24037M2' 'PL 2650303' 'PL 1211200'
#  'PL 2300400' 'PL 1650503' 'PL 1305200' 'VTL05110E1' 'PL 2205002'
#  'PL 2650203' 'PL 1450501' 'PL 2300300' 'PL 1252501' 'PL 2650103'
#  'PL 1655000' 'PL 2052002' 'PL 2403004' 'PL 1450003' 'PL 1702000'
#  'PL 121110A' 'PL 2213000' 'PL 1701501' 'PL 2212500' 'PL 2155001'
#  'PL 1202000' 'PL 21551B3' 'PL 1654501' 'PL 2405003' 'PL 265031B'
#  'PL 21551B2' 'PL 2201801' 'PL 2753500' 'PL 2403001' 'PL 16515M9'
#  'VTL1212000' 'PL 2201612' 'PL 2204301' 'PL 2650104' 'PL 2200906'
#  'PL 2200602' 'PL 1401501' 'PL 2212000' 'PL 240301B' 'PL 2213500'
#  'PL 1601501' 'PL 1907800' 'PL 1252502' 'PL 1403500' 'PL 245000A'
#  'PL 1651601' 'PL 160102B' 'VTL06000AA' 'PL 1902501' 'PL 140100B'
#  'PL 1651502' 'PL 1908001' 'PL 1456002' 'PL 140100G' 'PL 1654502'
#  'PL 2200604' 'PL 1650501' 'PL 2401000' 'VTL0512000' 'PL 1305500'
#  'PL 1306504' 'PL 1401701' 'PL 1201402' 'PL 140251C' 'VTL05110EA'
#  'PL 1601504' 'PL 2155600' 'ED 6512001' 'PL 2200605' 'PL 2154001'
#  'PL 2650400' 'PL 1306503' 'PL 1200509' 'PL 1653001' 'VTL11920U4'
#  'PL 1657200' 'PL 2215000' 'PL 21551B5' 'PL 1450502' 'PL 240301A'
#  'PL 2253002' 'PL 2203900' 'PL 2203100' 'TAX18140A1' 'PL 1703000'
#  'PL 1651508' 'PL 140100F' 'PL 2250500' 'PL 145004A' 'PL 1200512'
#  'PL 1650502' 'AM 0353000' 'PL 1306501' 'PL 1200504' 'VTL11920M3'
#  'PL 265033S' 'TAX181400D' 'PL 2702001' 'PL 125270T' 'PL 1651600'
#  'PL 1701005' 'PL 2200907' 'PL 1205003' 'PL 1200503' 'PL 1657300'
#  'PL 2155002' 'PL 2251002' 'PL 2650300' 'PL 2650206' 'PL 130751A'
#  'PL 1907901' 'VTL05110A1' 'VTL119203M' 'PL 2204500' 'ABC0064B00'
#  'PL 1304003' 'PL 1451400' 'PL 1753000' 'VTL11920E2' 'PL 2405001'
#  'PL 2215500' 'PL 1051500' 'PL 26503F3' 'PL 1200800' 'PL 1302502'
#  'PL 120003H' 'VTL11920D2' 'PL 2203403' 'PL 2201602' 'PL 2200603'
#  'PL 2400600' 'PL 1305001' 'PL 1761500' 'PL 1051700' 'PL 1601002'
#  'PL 1753500' 'PL 1200511' 'PL 1781000' 'PL 2155007' 'PL 1303001'
#  'VTL06002AB' 'PL 2650901' 'PL 1501500' 'PL 13052A1' 'PL 1201300'
#  'PL 1908600' 'VTL05110E2' 'ED 6512000' 'PL 1403002' 'PL 2754000'
#  'PL 2302502' 'PL 21551B4' 'PL 1200003' 'VTL05110AA' 'PL 2052001'
#  'PL 1350500' 'PL 1200600' 'COR0168T00' 'PL 2402100' 'PL 1554001'
#  'PL 145004B' 'PL 12005A3' 'PL 2051001' 'PL 1553006' 'PL 2205500'
#  'PL 1651001' 'PL 1451500' 'PL 1302501' 'PL 1252503' 'PL 2302000'
#  'PL 1403003' 'PL 2151101' 'PL 2155200' 'PL 1150001' 'PL 130960T'
#  'PL 245000B' 'PL 1907900' 'PL 1907902' 'PL 1701002' 'VTL11920M1'
#  'VTL1192E1C' 'PL 2000000' 'PL 4602001' 'PL 1907801' 'VTL11920M4'
#  'PL 27002MA' 'ABC0065000' 'VTL119202U' 'PL 2200903' 'PL 2155202'
#  'PL 1701001' 'PL 1580500' 'AM 0353A01' 'VTL0511D01' 'PL 2251001'
#  'PL 2214500' 'PL 1303002' 'PL 1752500' 'GCI0000000' 'PL 2400800'
#  'PL 2302500' 'ACA0250500' 'PL 155250Z' 'PL 1553000' 'PL 2204401'
#  'PL 2600000' 'PL 1554002' 'PL 2150000' 'PL 1902601' 'PL 120053A'
#  'VTL0510007' 'PL 2403703' 'PL 1906001' 'PL 2650208' 'PL 1200507'
#  'PL 1554200' 'PL 1908F02' 'PL 1201200' 'ACA0251100' 'PL 2751500'
#  'PL 2253001' 'PL 1706501' 'PL 2754002' 'PL 165154B' 'TAX18140B3'
#  'PL 1303501' 'PL 165154A' 'PL 13052A2' 'PL 2650205' 'PL 1211300'
#  'VTL05110A2' 'PL 2302501' 'PL 1401502' 'PL 1306502' 'PL 2056500'
#  'PL 2204402' 'PL 2155201' 'PL 1305003' 'PL 1403004' 'PL 265101B'
#  'PL 2702500' 'PL 2303401' 'PL 2400602' 'VTL1192E1B' 'TAX181700D'
#  'LOC00000AF']
# ARREST_BORO ['K' 'M' 'S' 'B' 'Q']
# AGE_GROUP ['25-44' '18-24' '45-64' '<18' '65+']
# PERP_RACE ['WHITE' 'BLACK' 'WHITE HISPANIC' 'BLACK HISPANIC'
#  'AMERICAN INDIAN/ALASKAN NATIVE' 'ASIAN / PACIFIC ISLANDER' 'UNKNOWN']

# %% [markdown]
# ## because there are so many symbolic variables with multiple values, we dummify the variables and encode them as numbers.

# %%
df = dummify(data, vars["symbolic"])

# %%
# Age group mapping
age_map = {"18-24": 1, "25-44": 2, "45-64": 3, "65+": 4, "<18": 0}
df["AGE_GROUP"] = data["AGE_GROUP"].map(age_map).fillna(-1)

# Encode race
race_encoder = {race: idx for idx, race in enumerate(data["PERP_RACE"].unique())}
df["PERP_RACE"] = data["PERP_RACE"].map(race_encoder)

df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD  KY_CD LAW_CAT_CD  ARREST_PRECINCT  \
# 0   167627343  2017-08-01  779.0  126.0          F               62
# 1   140205878  2014-12-16  750.0  359.0          M               25
# 2   141497929  2015-03-19  639.0  361.0          M               30
# 3    61262720  2009-04-29  969.0  881.0          M               28
# 4    71392833  2010-02-18  567.0  235.0          M              120
#
#    JURISDICTION_CODE PERP_SEX  X_COORD_CD  Y_COORD_CD  ...  AGE_GROUP_<18  \
# 0                0.0        M    987500.0    157358.0  ...          False
# 1                4.0        M   1004138.0    226326.0  ...          False
# 2                0.0        M    999751.0    241188.0  ...          False
# 3                0.0        M    999537.0    232842.0  ...          False
# 4                0.0        M    944398.0    165687.0  ...          False
#
#    PERP_RACE_AMERICAN INDIAN/ALASKAN NATIVE  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   PERP_RACE_ASIAN / PACIFIC ISLANDER  PERP_RACE_BLACK  \
# 0                              False            False
# 1                              False             True
# 2                              False            False
# 3                              False             True
# 4                              False            False
#
#    PERP_RACE_BLACK HISPANIC  PERP_RACE_UNKNOWN  PERP_RACE_WHITE  \
# 0                     False              False             True
# 1                     False              False            False
# 2                     False              False            False
# 3                     False              False            False
# 4                     False              False             True
#
#    PERP_RACE_WHITE HISPANIC  AGE_GROUP  PERP_RACE
# 0                     False          2          0
# 1                     False          2          1
# 2                      True          1          2
# 3                     False          2          1
# 4                     False          2          0
#
# [5 rows x 605 columns]
